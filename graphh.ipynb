# %% [markdown]
# <a href="https://colab.research.google.com/github/akashdolani/odoo/blob/main/graphh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
salary=[40000,42500,45000,47500]
cgpa=[7,8,8.5,9]
plt.plot(salary,cgpa)
plt.title("salary vs cgpa")
plt.xlabel("salary")
plt.ylabel("cgpa")
plt.show()
